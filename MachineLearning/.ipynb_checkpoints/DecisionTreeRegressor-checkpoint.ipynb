# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("df.csv")

# %%
df
# Out:
#       Unnamed: 0     ID        Country  Fulfill Via  Shipment Mode  \
# 0              1      3        Vietnam            0            1.0
# 1              3     15        Vietnam            0            1.0
# 2              4     16        Vietnam            0            1.0
# 3              5     23        Nigeria            0            1.0
# 4              6     44         Zambia            0            1.0
# ...          ...    ...            ...          ...            ...
# 8274       10319  86818       Zimbabwe            1            2.0
# 8275       10320  86819  Côte d'Ivoire            1            2.0
# 8276       10321  86821         Zambia            1            2.0
# 8277       10322  86822       Zimbabwe            1            2.0
# 8278       10323  86823       Zimbabwe            1            2.0
#
#      Scheduled Delivery Date Delivered to Client Date Delivery Recorded Date  \
# 0                  14-Nov-06                14-Nov-06              14-Nov-06
# 1                   1-Sep-06                 1-Sep-06               1-Sep-06
# 2                  11-Aug-06                11-Aug-06              11-Aug-06
# 3                  28-Sep-06                28-Sep-06              28-Sep-06
# 4                   8-Jan-07                 8-Jan-07               8-Jan-07
# ...                      ...                      ...                    ...
# 8274               31-Jul-15                15-Jul-15              20-Jul-15
# 8275               31-Jul-15                 6-Aug-15               7-Aug-15
# 8276               31-Aug-15                25-Aug-15               3-Sep-15
# 8277                9-Sep-15                 4-Aug-15              11-Aug-15
# 8278               31-Aug-15                 4-Aug-15              11-Aug-15
#
#       Product Group Sub Classification  ...  \
# 0                 1          Pediatric  ...
# 1                 1              Adult  ...
# 2                 1              Adult  ...
# 3                 1          Pediatric  ...
# 4                 1          Pediatric  ...
# ...             ...                ...  ...
# 8274              1          Pediatric  ...
# 8275              1              Adult  ...
# 8276              1              Adult  ...
# 8277              1              Adult  ...
# 8278              1          Pediatric  ...
#
#                             Dosage Form Unit of Measure (Per Pack)  \
# 0                       Oral suspension                        240
# 1                                Tablet                         60
# 2                               Capsule                         60
# 3                         Oral solution                        240
# 4                               Capsule                         90
# ...                                 ...                        ...
# 8274  Chewable/dispersible tablet - FDC                         60
# 8275                       Tablet - FDC                         60
# 8276                       Tablet - FDC                         30
# 8277                       Tablet - FDC                         60
# 8278  Chewable/dispersible tablet - FDC                         60
#
#      Line Item Quantity Line Item Value  Pack Price  Unit Price  \
# 0                  1000         6200.00        6.20        0.03
# 1                 31920       127360.80        3.99        0.07
# 2                 38000       121600.00        3.20        0.05
# 3                   416         2225.60        5.35        0.02
# 4                   135         4374.00       32.40        0.36
# ...                 ...             ...         ...         ...
# 8274             166571       599655.60        3.60        0.06
# 8275              21072       137389.44        6.52        0.11
# 8276             514526      5140114.74        9.99        0.33
# 8277              17465       113871.80        6.52        0.11
# 8278              36639        72911.61        1.99        0.03
#
#                   Manufacturing Site  First Line Designation  new_country  \
# 0          Aurobindo Unit III, India                       1            1
# 1      Ranbaxy, Paonta Shahib, India                       1            1
# 2          Aurobindo Unit III, India                       1            1
# 3          Aurobindo Unit III, India                       1            2
# 4      MSD South Granville Australia                       1            3
# ...                              ...                     ...          ...
# 8274      Mylan,  H-12 & H-13, India                       0            6
# 8275    Hetero Unit III Hyderabad IN                       0            7
# 8276   Cipla Ltd A-42 MIDC Mahar. IN                       0            3
# 8277  Mylan (formerly Matrix) Nashik                       1            6
# 8278               Cipla, Goa, India                       0            6
#
#      new_vendors
# 0              1
# 1              2
# 2              1
# 3              1
# 4              3
# ...          ...
# 8274          21
# 8275          21
# 8276          21
# 8277          21
# 8278          21
#
# [8279 rows x 23 columns]

# %%
x = pd.read_csv("X.csv")

# %%
x
# Out:
#       Unnamed: 0  Fulfill Via  Shipment Mode  Product Group  \
# 0              1            0            1.0              1
# 1              3            0            1.0              1
# 2              4            0            1.0              1
# 3              5            0            1.0              1
# 4              6            0            1.0              1
# ...          ...          ...            ...            ...
# 8274       10319            1            2.0              1
# 8275       10320            1            2.0              1
# 8276       10321            1            2.0              1
# 8277       10322            1            2.0              1
# 8278       10323            1            2.0              1
#
#       Unit of Measure (Per Pack)  Line Item Quantity  Pack Price  Unit Price  \
# 0                            240                1000        6.20        0.03
# 1                             60               31920        3.99        0.07
# 2                             60               38000        3.20        0.05
# 3                            240                 416        5.35        0.02
# 4                             90                 135       32.40        0.36
# ...                          ...                 ...         ...         ...
# 8274                          60              166571        3.60        0.06
# 8275                          60               21072        6.52        0.11
# 8276                          30              514526        9.99        0.33
# 8277                          60               17465        6.52        0.11
# 8278                          60               36639        1.99        0.03
#
#       First Line Designation  new_country
# 0                          1            1
# 1                          1            1
# 2                          1            1
# 3                          1            2
# 4                          1            3
# ...                      ...          ...
# 8274                       0            6
# 8275                       0            7
# 8276                       0            3
# 8277                       1            6
# 8278                       0            6
#
# [8279 rows x 10 columns]

# %%
y = pd.read_csv("Y.csv")

# %%
y.drop("Unnamed: 0", axis=1, inplace=True)

# %%
y
# Out:
#       new_vendors
# 0               1
# 1               2
# 2               1
# 3               1
# 4               3
# ...           ...
# 8274           21
# 8275           21
# 8276           21
# 8277           21
# 8278           21
#
# [8279 rows x 1 columns]

# %%
from sklearn.tree import DecisionTreeRegressor
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score

# %%
 X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.33, random_state=42)

# %%
model = DecisionTreeRegressor()

# %%
model.fit(X_train, y_train)
# Out:
# DecisionTreeRegressor()

# %%
pred = model.predict(X_test)

# %%
pred
# Out:
# array([ 1., 21.,  9., ...,  1.,  1., 21.])

# %%
np_y_test = np.array(y_test)

# %%
np_y_test
# Out:
# array([[ 1],
#        [21],
#        [ 9],
#        ...,
#        [ 5],
#        [ 8],
#        [21]], dtype=int64)

# %%
accuracy_score(y_test, pred)
# Out:
# 0.8660812294182217

# %%
print("Accuracy: " + accuracy_score(y_test, pred))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [19], in <cell line: 1>()
# ----> 1 print("Accuracy: " +accuracy_score)
#
# TypeError: can only concatenate str (not "function") to str
