# %%
import pandas as pd
import numpy as np

# %%
df= pd.read_csv("cleaned_data.csv")

# %%
df
# Out:
#           ID Project Code            PQ # PO / SO # ASN/DN #        Country  \
# 0          1   100-CI-T01  Pre-PQ Process    SCMS-4    ASN-8  Côte d'Ivoire
# 1          3   108-VN-T01  Pre-PQ Process   SCMS-13   ASN-85        Vietnam
# 2          4   100-CI-T01  Pre-PQ Process   SCMS-20   ASN-14  Côte d'Ivoire
# 3         15   108-VN-T01  Pre-PQ Process   SCMS-78   ASN-50        Vietnam
# 4         16   108-VN-T01  Pre-PQ Process   SCMS-81   ASN-55        Vietnam
# ...      ...          ...             ...       ...      ...            ...
# 10319  86818   103-ZW-T30       FPQ-15197  SO-50020  DN-4307       Zimbabwe
# 10320  86819   104-CI-T30       FPQ-15259  SO-50102  DN-4313  Côte d'Ivoire
# 10321  86821   110-ZM-T30       FPQ-14784  SO-49600  DN-4316         Zambia
# 10322  86822   200-ZW-T30       FPQ-16523  SO-51680  DN-4334       Zimbabwe
# 10323  86823   103-ZW-T30       FPQ-15197  SO-50022  DN-4336       Zimbabwe
#
#       Managed By  Fulfill Via Vendor INCO Term  Shipment Mode  ...  \
# 0       PMO - US  Direct Drop              EXW            1.0  ...
# 1       PMO - US  Direct Drop              EXW            1.0  ...
# 2       PMO - US  Direct Drop              FCA            1.0  ...
# 3       PMO - US  Direct Drop              EXW            1.0  ...
# 4       PMO - US  Direct Drop              EXW            1.0  ...
# ...          ...          ...              ...            ...  ...
# 10319   PMO - US     From RDC   N/A - From RDC            2.0  ...
# 10320   PMO - US     From RDC   N/A - From RDC            2.0  ...
# 10321   PMO - US     From RDC   N/A - From RDC            2.0  ...
# 10322   PMO - US     From RDC   N/A - From RDC            2.0  ...
# 10323   PMO - US     From RDC   N/A - From RDC            2.0  ...
#
#       Unit of Measure (Per Pack) Line Item Quantity Line Item Value  \
# 0                             30                 19          551.00
# 1                            240               1000         6200.00
# 2                            100                500        40000.00
# 3                             60              31920       127360.80
# 4                             60              38000       121600.00
# ...                          ...                ...             ...
# 10319                         60             166571       599655.60
# 10320                         60              21072       137389.44
# 10321                         30             514526      5140114.74
# 10322                         60              17465       113871.80
# 10323                         60              36639        72911.61
#
#       Pack Price Unit Price              Manufacturing Site  \
# 0          29.00       0.97      Ranbaxy Fine Chemicals LTD
# 1           6.20       0.03       Aurobindo Unit III, India
# 2          80.00       0.80   ABBVIE GmbH & Co.KG Wiesbaden
# 3           3.99       0.07   Ranbaxy, Paonta Shahib, India
# 4           3.20       0.05       Aurobindo Unit III, India
# ...          ...        ...                             ...
# 10319       3.60       0.06      Mylan,  H-12 & H-13, India
# 10320       6.52       0.11    Hetero Unit III Hyderabad IN
# 10321       9.99       0.33   Cipla Ltd A-42 MIDC Mahar. IN
# 10322       6.52       0.11  Mylan (formerly Matrix) Nashik
# 10323       1.99       0.03               Cipla, Goa, India
#
#       First Line Designation          Weight (Kilograms)  \
# 0                        Yes                          13
# 1                        Yes                         358
# 2                        Yes                         171
# 3                        Yes                        1855
# 4                        Yes                        7590
# ...                      ...                         ...
# 10319                     No     See DN-4307 (ID#:83920)
# 10320                     No     See DN-4313 (ID#:83921)
# 10321                     No  Weight Captured Separately
# 10322                    Yes                        1392
# 10323                     No  Weight Captured Separately
#
#                        Freight Cost (USD) Line Item Insurance (USD)
# 0                                  780.34                240.117626
# 1                                  4521.5                240.117626
# 2                                 1653.78                240.117626
# 3                                16007.06                240.117626
# 4                                45450.08                240.117626
# ...                                   ...                       ...
# 10319             See DN-4307 (ID#:83920)                705.790000
# 10320             See DN-4313 (ID#:83921)                161.710000
# 10321  Freight Included in Commodity Cost               5284.040000
# 10322  Freight Included in Commodity Cost                134.030000
# 10323  Freight Included in Commodity Cost                 85.820000
#
# [10324 rows x 33 columns]

# %%
df.isnull().sum()
# Out:
# ID                                 0
# Project Code                       0
# PQ #                               0
# PO / SO #                          0
# ASN/DN #                           0
# Country                            0
# Managed By                         0
# Fulfill Via                        0
# Vendor INCO Term                   0
# Shipment Mode                    360
# PQ First Sent to Client Date       0
# PO Sent to Vendor Date             0
# Scheduled Delivery Date            0
# Delivered to Client Date           0
# Delivery Recorded Date             0
# Product Group                      0
# Sub Classification                 0
# Vendor                             0
# Item Description                   0
# Molecule/Test Type                 0
# Brand                              0
# Dosage                          1736
# Dosage Form                        0
# Unit of Measure (Per Pack)         0
# Line Item Quantity                 0
# Line Item Value                    0
# Pack Price                         0
# Unit Price                         0
# Manufacturing Site                 0
# First Line Designation             0
# Weight (Kilograms)                 0
# Freight Cost (USD)                 0
# Line Item Insurance (USD)          0
# dtype: int64

# %%
df.dropna(inplace=True)

# %%
df.drop(["Project Code"], axis=1, inplace=True)

# %%
P_group = {
    'HRDT' : 0, 'ARV' : 1, 'ACT': 2, 'MRDT': 3, 'ANTM': 4
}

# %%
df["Product Group"] = df["Product Group"].replace(P_group)

# %%
df.drop(["PO Sent to Vendor Date", "Item Description", "Molecule/Test Type", "PQ First Sent to Client Date", "Managed By"], axis=1, inplace=True)

# %%
df
# Out:
#           ID            PQ # PO / SO # ASN/DN #        Country  Fulfill Via  \
# 1          3  Pre-PQ Process   SCMS-13   ASN-85        Vietnam  Direct Drop
# 3         15  Pre-PQ Process   SCMS-78   ASN-50        Vietnam  Direct Drop
# 4         16  Pre-PQ Process   SCMS-81   ASN-55        Vietnam  Direct Drop
# 5         23  Pre-PQ Process   SCMS-87   ASN-57        Nigeria  Direct Drop
# 6         44  Pre-PQ Process  SCMS-139  ASN-130         Zambia  Direct Drop
# ...      ...             ...       ...      ...            ...          ...
# 10319  86818       FPQ-15197  SO-50020  DN-4307       Zimbabwe     From RDC
# 10320  86819       FPQ-15259  SO-50102  DN-4313  Côte d'Ivoire     From RDC
# 10321  86821       FPQ-14784  SO-49600  DN-4316         Zambia     From RDC
# 10322  86822       FPQ-16523  SO-51680  DN-4334       Zimbabwe     From RDC
# 10323  86823       FPQ-15197  SO-50022  DN-4336       Zimbabwe     From RDC
#
#       Vendor INCO Term  Shipment Mode Scheduled Delivery Date  \
# 1                  EXW            1.0               14-Nov-06
# 3                  EXW            1.0                1-Sep-06
# 4                  EXW            1.0               11-Aug-06
# 5                  EXW            1.0               28-Sep-06
# 6                  DDU            1.0                8-Jan-07
# ...                ...            ...                     ...
# 10319   N/A - From RDC            2.0               31-Jul-15
# 10320   N/A - From RDC            2.0               31-Jul-15
# 10321   N/A - From RDC            2.0               31-Aug-15
# 10322   N/A - From RDC            2.0                9-Sep-15
# 10323   N/A - From RDC            2.0               31-Aug-15
#
#       Delivered to Client Date  ... Unit of Measure (Per Pack)  \
# 1                    14-Nov-06  ...                        240
# 3                     1-Sep-06  ...                         60
# 4                    11-Aug-06  ...                         60
# 5                    28-Sep-06  ...                        240
# 6                     8-Jan-07  ...                         90
# ...                        ...  ...                        ...
# 10319                15-Jul-15  ...                         60
# 10320                 6-Aug-15  ...                         60
# 10321                25-Aug-15  ...                         30
# 10322                 4-Aug-15  ...                         60
# 10323                 4-Aug-15  ...                         60
#
#        Line Item Quantity Line Item Value Pack Price Unit Price  \
# 1                    1000         6200.00       6.20       0.03
# 3                   31920       127360.80       3.99       0.07
# 4                   38000       121600.00       3.20       0.05
# 5                     416         2225.60       5.35       0.02
# 6                     135         4374.00      32.40       0.36
# ...                   ...             ...        ...        ...
# 10319              166571       599655.60       3.60       0.06
# 10320               21072       137389.44       6.52       0.11
# 10321              514526      5140114.74       9.99       0.33
# 10322               17465       113871.80       6.52       0.11
# 10323               36639        72911.61       1.99       0.03
#
#                    Manufacturing Site First Line Designation  \
# 1           Aurobindo Unit III, India                    Yes
# 3       Ranbaxy, Paonta Shahib, India                    Yes
# 4           Aurobindo Unit III, India                    Yes
# 5           Aurobindo Unit III, India                    Yes
# 6       MSD South Granville Australia                    Yes
# ...                               ...                    ...
# 10319      Mylan,  H-12 & H-13, India                     No
# 10320    Hetero Unit III Hyderabad IN                     No
# 10321   Cipla Ltd A-42 MIDC Mahar. IN                     No
# 10322  Mylan (formerly Matrix) Nashik                    Yes
# 10323               Cipla, Goa, India                     No
#
#                Weight (Kilograms)                  Freight Cost (USD)  \
# 1                             358                              4521.5
# 3                            1855                            16007.06
# 4                            7590                            45450.08
# 5                             504                             5920.42
# 6                             328  Freight Included in Commodity Cost
# ...                           ...                                 ...
# 10319     See DN-4307 (ID#:83920)             See DN-4307 (ID#:83920)
# 10320     See DN-4313 (ID#:83921)             See DN-4313 (ID#:83921)
# 10321  Weight Captured Separately  Freight Included in Commodity Cost
# 10322                        1392  Freight Included in Commodity Cost
# 10323  Weight Captured Separately  Freight Included in Commodity Cost
#
#        Line Item Insurance (USD)
# 1                     240.117626
# 3                     240.117626
# 4                     240.117626
# 5                     240.117626
# 6                     240.117626
# ...                          ...
# 10319                 705.790000
# 10320                 161.710000
# 10321                5284.040000
# 10322                 134.030000
# 10323                  85.820000
#
# [8279 rows x 27 columns]

# %%
y_temp = df["Vendor"]

# %%
final_y =  pd.factorize(y_temp)[0]+1

# %%
country = df["Country"]

# %%
final_country = pd.factorize(country)[0]+1
final_country
# Out:
# array([1, 1, 1, ..., 3, 6, 6], dtype=int64)

# %%
df["Country"].replace(final_country, inplace=True)

# %%
df.head()
# Out:
#    ID            PQ # PO / SO # ASN/DN #  Country  Fulfill Via  \
# 1   3  Pre-PQ Process   SCMS-13   ASN-85  Vietnam  Direct Drop
# 3  15  Pre-PQ Process   SCMS-78   ASN-50  Vietnam  Direct Drop
# 4  16  Pre-PQ Process   SCMS-81   ASN-55  Vietnam  Direct Drop
# 5  23  Pre-PQ Process   SCMS-87   ASN-57  Nigeria  Direct Drop
# 6  44  Pre-PQ Process  SCMS-139  ASN-130   Zambia  Direct Drop
#
#   Vendor INCO Term  Shipment Mode Scheduled Delivery Date  \
# 1              EXW            1.0               14-Nov-06
# 3              EXW            1.0                1-Sep-06
# 4              EXW            1.0               11-Aug-06
# 5              EXW            1.0               28-Sep-06
# 6              DDU            1.0                8-Jan-07
#
#   Delivered to Client Date  ... Unit of Measure (Per Pack)  \
# 1                14-Nov-06  ...                        240
# 3                 1-Sep-06  ...                         60
# 4                11-Aug-06  ...                         60
# 5                28-Sep-06  ...                        240
# 6                 8-Jan-07  ...                         90
#
#    Line Item Quantity Line Item Value Pack Price Unit Price  \
# 1                1000          6200.0       6.20       0.03
# 3               31920        127360.8       3.99       0.07
# 4               38000        121600.0       3.20       0.05
# 5                 416          2225.6       5.35       0.02
# 6                 135          4374.0      32.40       0.36
#
#               Manufacturing Site First Line Designation  Weight (Kilograms)  \
# 1      Aurobindo Unit III, India                    Yes                 358
# 3  Ranbaxy, Paonta Shahib, India                    Yes                1855
# 4      Aurobindo Unit III, India                    Yes                7590
# 5      Aurobindo Unit III, India                    Yes                 504
# 6  MSD South Granville Australia                    Yes                 328
#
#                    Freight Cost (USD)  Line Item Insurance (USD)
# 1                              4521.5                 240.117626
# 3                            16007.06                 240.117626
# 4                            45450.08                 240.117626
# 5                             5920.42                 240.117626
# 6  Freight Included in Commodity Cost                 240.117626
#
# [5 rows x 27 columns]

# %%
data_frame = {
    "new_Country": final_country
}

# %%
df["new_country"] = final_country
df["new_vendors"] = final_y

# %%
df.tail(50)
# Out:
#           ID        Country  Fulfill Via  Shipment Mode  \
# 10274  86740     Congo, DRC            1            1.0
# 10275  86741     Congo, DRC            1            1.0
# 10276  86743        Nigeria            1            3.0
# 10277  86746         Rwanda            1            2.0
# 10278  86747         Rwanda            1            2.0
# 10279  86749         Uganda            1            2.0
# 10280  86750  Côte d'Ivoire            1            2.0
# 10281  86751  Côte d'Ivoire            1            2.0
# 10282  86756         Zambia            1            2.0
# 10283  86757        Nigeria            1            3.0
# 10284  86758  Côte d'Ivoire            1            2.0
# 10285  86772        Nigeria            1            3.0
# 10286  86773         Uganda            1            2.0
# 10287  86774     Congo, DRC            1            1.0
# 10288  86781         Uganda            1            2.0
# 10289  86782     Mozambique            1            2.0
# 10290  86784         Zambia            1            2.0
# 10291  86785         Rwanda            1            2.0
# 10292  86786         Uganda            1            2.0
# 10293  86787         Rwanda            1            1.0
# 10294  86788        Burundi            1            1.0
# 10295  86789        Burundi            1            1.0
# 10296  86790        Nigeria            1            3.0
# 10297  86791     Congo, DRC            1            1.0
# 10298  86795        Burundi            1            1.0
# 10299  86796  Côte d'Ivoire            1            2.0
# 10300  86797         Uganda            1            2.0
# 10301  86798         Uganda            1            2.0
# 10302  86799       Zimbabwe            1            2.0
# 10303  86800     Mozambique            1            2.0
# 10304  86801     Mozambique            1            2.0
# 10305  86802     Mozambique            1            2.0
# 10306  86803     Mozambique            1            2.0
# 10307  86805       Zimbabwe            1            2.0
# 10308  86806         Zambia            1            2.0
# 10309  86807         Zambia            1            2.0
# 10310  86808         Uganda            1            2.0
# 10311  86809         Uganda            1            2.0
# 10312  86810         Uganda            1            2.0
# 10313  86812  Côte d'Ivoire            1            2.0
# 10314  86813        Nigeria            1            3.0
# 10315  86814        Nigeria            1            3.0
# 10316  86815        Nigeria            1            3.0
# 10317  86816        Nigeria            1            1.0
# 10318  86817       Zimbabwe            1            2.0
# 10319  86818       Zimbabwe            1            2.0
# 10320  86819  Côte d'Ivoire            1            2.0
# 10321  86821         Zambia            1            2.0
# 10322  86822       Zimbabwe            1            2.0
# 10323  86823       Zimbabwe            1            2.0
#
#       Scheduled Delivery Date Delivered to Client Date Delivery Recorded Date  \
# 10274               30-Jan-15                18-Feb-15              23-Feb-15
# 10275               30-Jan-15                18-Feb-15              23-Feb-15
# 10276               31-Oct-14                30-Oct-14               3-Nov-14
# 10277               14-Jan-15                13-Nov-14              14-Nov-14
# 10278               16-Feb-15                14-Jan-15              19-Jan-15
# 10279               15-Jan-15                17-Dec-14              22-Dec-14
# 10280               28-Nov-14                 2-Dec-14               8-Dec-14
# 10281               28-Nov-14                 2-Dec-14               8-Dec-14
# 10282               30-Jan-15                19-Feb-15              20-Feb-15
# 10283               30-Jan-15                29-Dec-14               6-Jan-15
# 10284               16-Feb-15                19-Jan-15              27-Jan-15
# 10285               30-Jan-15                14-Jan-15              20-Jan-15
# 10286                6-Feb-15                30-Jan-15               2-Feb-15
# 10287               14-Apr-15                14-Apr-15              14-Apr-15
# 10288               16-Mar-15                12-Mar-15              17-Mar-15
# 10289               30-Jun-15                10-Apr-15              20-Apr-15
# 10290               27-Feb-15                25-Mar-15              26-Mar-15
# 10291               31-Mar-15                24-Mar-15              24-Mar-15
# 10292               31-Mar-15                15-May-15              17-May-15
# 10293               24-Apr-15                 4-May-15               8-May-15
# 10294               29-May-15                25-Mar-15              30-Mar-15
# 10295               29-May-15                25-Mar-15              30-Mar-15
# 10296               30-Jun-15                18-Mar-15              20-Mar-15
# 10297                6-May-15                 6-Jul-15               6-Jul-15
# 10298               30-Jun-15                22-Apr-15              23-Apr-15
# 10299               19-Jun-15                16-Apr-15              20-Apr-15
# 10300               30-Apr-15                22-Apr-15              24-Apr-15
# 10301               15-Jun-15                14-May-15              15-May-15
# 10302               30-Apr-15                 8-Apr-15              14-Apr-15
# 10303               31-May-15                 9-Jun-15              15-Jun-15
# 10304               29-May-15                15-Jun-15              15-Jun-15
# 10305               29-May-15                 9-Jun-15              15-Jun-15
# 10306               29-May-15                15-Jun-15              15-Jun-15
# 10307               30-Apr-15                30-Apr-15              30-Apr-15
# 10308               29-May-15                15-May-15              15-May-15
# 10309               29-May-15                15-May-15              15-May-15
# 10310               30-Jun-15                 4-Jun-15              15-Jun-15
# 10311               30-Jun-15                 4-Jun-15              15-Jun-15
# 10312               15-Jun-15                 4-Jun-15              15-Jun-15
# 10313               29-May-15                29-May-15              18-Jun-15
# 10314               30-Jun-15                15-May-15              22-May-15
# 10315               30-Jun-15                15-May-15              22-May-15
# 10316                2-Jun-15                15-May-15              22-May-15
# 10317               30-Jun-15                22-Jun-15              29-Jun-15
# 10318               31-Jul-15                15-Jul-15              20-Jul-15
# 10319               31-Jul-15                15-Jul-15              20-Jul-15
# 10320               31-Jul-15                 6-Aug-15               7-Aug-15
# 10321               31-Aug-15                25-Aug-15               3-Sep-15
# 10322                9-Sep-15                 4-Aug-15              11-Aug-15
# 10323               31-Aug-15                 4-Aug-15              11-Aug-15
#
#        Product Group Sub Classification         Vendor  ...  \
# 10274              1              Adult  SCMS from RDC  ...
# 10275              1              Adult  SCMS from RDC  ...
# 10276              1              Adult  SCMS from RDC  ...
# 10277              1          Pediatric  SCMS from RDC  ...
# 10278              1              Adult  SCMS from RDC  ...
# 10279              1              Adult  SCMS from RDC  ...
# 10280              1              Adult  SCMS from RDC  ...
# 10281              1              Adult  SCMS from RDC  ...
# 10282              1              Adult  SCMS from RDC  ...
# 10283              1              Adult  SCMS from RDC  ...
# 10284              1              Adult  SCMS from RDC  ...
# 10285              1              Adult  SCMS from RDC  ...
# 10286              1          Pediatric  SCMS from RDC  ...
# 10287              1              Adult  SCMS from RDC  ...
# 10288              1          Pediatric  SCMS from RDC  ...
# 10289              1          Pediatric  SCMS from RDC  ...
# 10290              1              Adult  SCMS from RDC  ...
# 10291              1          Pediatric  SCMS from RDC  ...
# 10292              1              Adult  SCMS from RDC  ...
# 10293              1              Adult  SCMS from RDC  ...
# 10294              1              Adult  SCMS from RDC  ...
# 10295              1          Pediatric  SCMS from RDC  ...
# 10296              1              Adult  SCMS from RDC  ...
# 10297              1          Pediatric  SCMS from RDC  ...
# 10298              1              Adult  SCMS from RDC  ...
# 10299              1              Adult  SCMS from RDC  ...
# 10300              1              Adult  SCMS from RDC  ...
# 10301              1              Adult  SCMS from RDC  ...
# 10302              1          Pediatric  SCMS from RDC  ...
# 10303              1              Adult  SCMS from RDC  ...
# 10304              1              Adult  SCMS from RDC  ...
# 10305              1              Adult  SCMS from RDC  ...
# 10306              1              Adult  SCMS from RDC  ...
# 10307              1          Pediatric  SCMS from RDC  ...
# 10308              1          Pediatric  SCMS from RDC  ...
# 10309              1              Adult  SCMS from RDC  ...
# 10310              1          Pediatric  SCMS from RDC  ...
# 10311              1          Pediatric  SCMS from RDC  ...
# 10312              1          Pediatric  SCMS from RDC  ...
# 10313              1              Adult  SCMS from RDC  ...
# 10314              1          Pediatric  SCMS from RDC  ...
# 10315              1              Adult  SCMS from RDC  ...
# 10316              1              Adult  SCMS from RDC  ...
# 10317              1              Adult  SCMS from RDC  ...
# 10318              1          Pediatric  SCMS from RDC  ...
# 10319              1          Pediatric  SCMS from RDC  ...
# 10320              1              Adult  SCMS from RDC  ...
# 10321              1              Adult  SCMS from RDC  ...
# 10322              1              Adult  SCMS from RDC  ...
# 10323              1          Pediatric  SCMS from RDC  ...
#
#                              Dosage Form Unit of Measure (Per Pack)  \
# 10274                       Tablet - FDC                         60
# 10275                             Tablet                         60
# 10276                       Tablet - FDC                         30
# 10277  Chewable/dispersible tablet - FDC                         60
# 10278                       Tablet - FDC                         30
# 10279                             Tablet                         30
# 10280                             Tablet                         30
# 10281                       Tablet - FDC                         60
# 10282                       Tablet - FDC                         30
# 10283                       Tablet - FDC                         60
# 10284                       Tablet - FDC                         60
# 10285                       Tablet - FDC                         30
# 10286  Chewable/dispersible tablet - FDC                         60
# 10287                       Tablet - FDC                         30
# 10288  Chewable/dispersible tablet - FDC                         60
# 10289                    Oral suspension                        240
# 10290                             Tablet                         60
# 10291                      Oral solution                        240
# 10292                       Tablet - FDC                         30
# 10293                             Tablet                         30
# 10294                       Tablet - FDC                         60
# 10295  Chewable/dispersible tablet - FDC                         60
# 10296                             Tablet                        120
# 10297  Chewable/dispersible tablet - FDC                         60
# 10298                       Tablet - FDC                         60
# 10299                       Tablet - FDC                         30
# 10300                       Tablet - FDC                         60
# 10301                             Tablet                         30
# 10302  Chewable/dispersible tablet - FDC                         60
# 10303                       Tablet - FDC                         30
# 10304                       Tablet - FDC                         60
# 10305                       Tablet - FDC                         60
# 10306                       Tablet - FDC                         30
# 10307  Chewable/dispersible tablet - FDC                         60
# 10308                             Tablet                         90
# 10309                       Tablet - FDC                         60
# 10310  Chewable/dispersible tablet - FDC                         60
# 10311  Chewable/dispersible tablet - FDC                         60
# 10312                             Tablet                         90
# 10313                             Tablet                         30
# 10314  Chewable/dispersible tablet - FDC                         60
# 10315                             Tablet                        120
# 10316                       Tablet - FDC                         60
# 10317                             Tablet                         30
# 10318  Chewable/dispersible tablet - FDC                         60
# 10319  Chewable/dispersible tablet - FDC                         60
# 10320                       Tablet - FDC                         60
# 10321                       Tablet - FDC                         30
# 10322                       Tablet - FDC                         60
# 10323  Chewable/dispersible tablet - FDC                         60
#
#       Line Item Quantity  Line Item Value  Pack Price  Unit Price  \
# 10274               3460         28060.60        8.11        0.14
# 10275               1976          3438.24        1.74        0.03
# 10276              57000        263340.00        4.62        0.15
# 10277                459           913.41        1.99        0.03
# 10278              49270        666130.40       13.52        0.45
# 10279              22500         72225.00        3.21        0.11
# 10280              32400        107892.00        3.33        0.11
# 10281              55995        365087.40        6.52        0.11
# 10282              18447         85225.14        4.62        0.15
# 10283             306992       2369978.24        7.72        0.13
# 10284             120000        926400.00        7.72        0.13
# 10285             296996       1369151.56        4.61        0.15
# 10286               5000         18650.00        3.73        0.06
# 10287              55300        539728.00        9.76        0.33
# 10288                273           982.80        3.60        0.06
# 10289              24871         37555.21        1.51        0.01
# 10290              71600        156088.00        2.18        0.04
# 10291               1820         12430.60        6.83        0.03
# 10292              27365        125605.35        4.59        0.15
# 10293                200           710.00        3.55        0.12
# 10294               1008          7781.76        7.72        0.13
# 10295                282           549.90        1.95        0.03
# 10296              13130        244743.20       18.64        0.16
# 10297                490           955.50        1.95        0.03
# 10298               1056          8152.32        7.72        0.13
# 10299               8250         37867.50        4.59        0.15
# 10300              21667        167269.24        7.72        0.13
# 10301              29998         93593.76        3.12        0.10
# 10302              47733         91647.36        1.92        0.03
# 10303             200000       1920000.00        9.60        0.32
# 10304              28516        220143.52        7.72        0.13
# 10305             300000       2316000.00        7.72        0.13
# 10306              16006         73467.54        4.59        0.15
# 10307              46752        168307.20        3.60        0.06
# 10308              15000         82500.00        5.50        0.06
# 10309               2016          5019.84        2.49        0.04
# 10310              18000         64800.00        3.60        0.06
# 10311              29287        105433.20        3.60        0.06
# 10312               6312         34716.00        5.50        0.06
# 10313              19996         62387.52        3.12        0.10
# 10314              10340         37224.00        3.60        0.06
# 10315              70000       1304800.00       18.64        0.16
# 10316              15000         97800.00        6.52        0.11
# 10317               6724         20978.88        3.12        0.10
# 10318             205243        738874.80        3.60        0.06
# 10319             166571        599655.60        3.60        0.06
# 10320              21072        137389.44        6.52        0.11
# 10321             514526       5140114.74        9.99        0.33
# 10322              17465        113871.80        6.52        0.11
# 10323              36639         72911.61        1.99        0.03
#
#                    Manufacturing Site  First Line Designation new_country  \
# 10274  Mylan (formerly Matrix) Nashik                       0          21
# 10275       Aurobindo Unit III, India                       0          21
# 10276          Aurobindo Unit VII, IN                       1           2
# 10277               Cipla, Goa, India                       0           5
# 10278  Mylan (formerly Matrix) Nashik                       0           5
# 10279      Strides, Bangalore, India.                       0          12
# 10280      Strides, Bangalore, India.                       0           7
# 10281       Aurobindo Unit III, India                       1           7
# 10282    Hetero Unit III Hyderabad IN                       1           3
# 10283               Cipla, Goa, India                       0           2
# 10284    Hetero Unit III Hyderabad IN                       0           7
# 10285    Hetero Unit III Hyderabad IN                       0           2
# 10286  Mylan (formerly Matrix) Nashik                       1          12
# 10287  Mylan (formerly Matrix) Nashik                       1          21
# 10288      Strides, Bangalore, India.                       0          12
# 10289       Aurobindo Unit III, India                       0          11
# 10290      Strides, Bangalore, India.                       0           3
# 10291       Aurobindo Unit III, India                       0           5
# 10292       Ranbaxy per Shasun Pharma                       1          12
# 10293  Mylan (formerly Matrix) Nashik                       1           5
# 10294   Hetero, Jadcherla, unit 5, IN                       0          32
# 10295      Mylan,  H-12 & H-13, India                       0          32
# 10296     ABBVIE Ludwigshafen Germany                       1           2
# 10297      Mylan,  H-12 & H-13, India                       0          21
# 10298  Mylan (formerly Matrix) Nashik                       0          32
# 10299          Cipla, Kurkumbh, India                       1           7
# 10300  Mylan (formerly Matrix) Nashik                       0          12
# 10301    Hetero Unit III Hyderabad IN                       0          12
# 10302               Cipla, Goa, India                       1           6
# 10303    Hetero Unit III Hyderabad IN                       1          11
# 10304    Hetero Unit III Hyderabad IN                       1          11
# 10305    Hetero Unit III Hyderabad IN                       1          11
# 10306   Hetero, Jadcherla, unit 5, IN                       1          11
# 10307               Cipla, Goa, India                       0           6
# 10308      Strides, Bangalore, India.                       0           3
# 10309    Hetero Unit III Hyderabad IN                       0           3
# 10310  Mylan (formerly Matrix) Nashik                       1          12
# 10311      Strides, Bangalore, India.                       0          12
# 10312      Strides, Bangalore, India.                       0          12
# 10313   Micro labs, Verna, Goa, India                       0           7
# 10314  Mylan (formerly Matrix) Nashik                       0           2
# 10315     ABBVIE Ludwigshafen Germany                       1           2
# 10316       Aurobindo Unit III, India                       1           2
# 10317      Strides, Bangalore, India.                       0           2
# 10318               Cipla, Goa, India                       0           6
# 10319      Mylan,  H-12 & H-13, India                       0           6
# 10320    Hetero Unit III Hyderabad IN                       0           7
# 10321   Cipla Ltd A-42 MIDC Mahar. IN                       0           3
# 10322  Mylan (formerly Matrix) Nashik                       1           6
# 10323               Cipla, Goa, India                       0           6
#
#        new_vendors
# 10274           21
# 10275           21
# 10276           21
# 10277           21
# 10278           21
# 10279           21
# 10280           21
# 10281           21
# 10282           21
# 10283           21
# 10284           21
# 10285           21
# 10286           21
# 10287           21
# 10288           21
# 10289           21
# 10290           21
# 10291           21
# 10292           21
# 10293           21
# 10294           21
# 10295           21
# 10296           21
# 10297           21
# 10298           21
# 10299           21
# 10300           21
# 10301           21
# 10302           21
# 10303           21
# 10304           21
# 10305           21
# 10306           21
# 10307           21
# 10308           21
# 10309           21
# 10310           21
# 10311           21
# 10312           21
# 10313           21
# 10314           21
# 10315           21
# 10316           21
# 10317           21
# 10318           21
# 10319           21
# 10320           21
# 10321           21
# 10322           21
# 10323           21
#
# [50 rows x 22 columns]

# %%
df.drop(["Line Item Insurance (USD)"], inplace=True, axis =1)

# %%
df.drop(["Vendor INCO Term"], inplace=True, axis =1)

# %%
df = df.drop(['Weight (Kilograms)', 'Freight Cost (USD)'], axis=1)
df = df.drop(['PQ #', 'PO / SO #', 'ASN/DN #'], axis=1)

# %%
df['Fulfill Via'] = df['Fulfill Via'].replace({'Direct Drop': 0, 'From RDC': 1})
df['First Line Designation'] = df['First Line Designation'].replace({'No': 0, 'Yes': 1})

# %%
df.head()
# Out:
#    ID  Country  Fulfill Via  Shipment Mode Scheduled Delivery Date  \
# 1   3  Vietnam            0            1.0               14-Nov-06
# 3  15  Vietnam            0            1.0                1-Sep-06
# 4  16  Vietnam            0            1.0               11-Aug-06
# 5  23  Nigeria            0            1.0               28-Sep-06
# 6  44   Zambia            0            1.0                8-Jan-07
#
#   Delivered to Client Date Delivery Recorded Date  Product Group  \
# 1                14-Nov-06              14-Nov-06              1
# 3                 1-Sep-06               1-Sep-06              1
# 4                11-Aug-06              11-Aug-06              1
# 5                28-Sep-06              28-Sep-06              1
# 6                 8-Jan-07               8-Jan-07              1
#
#   Sub Classification                                             Vendor  ...  \
# 1          Pediatric                           Aurobindo Pharma Limited  ...
# 3              Adult  SUN PHARMACEUTICAL INDUSTRIES LTD (RANBAXY LAB...  ...
# 4              Adult                           Aurobindo Pharma Limited  ...
# 5          Pediatric                           Aurobindo Pharma Limited  ...
# 6          Pediatric  MERCK SHARP & DOHME IDEA GMBH (FORMALLY MERCK ...  ...
#
#        Dosage Form Unit of Measure (Per Pack) Line Item Quantity  \
# 1  Oral suspension                        240               1000
# 3           Tablet                         60              31920
# 4          Capsule                         60              38000
# 5    Oral solution                        240                416
# 6          Capsule                         90                135
#
#    Line Item Value  Pack Price  Unit Price             Manufacturing Site  \
# 1           6200.0        6.20        0.03      Aurobindo Unit III, India
# 3         127360.8        3.99        0.07  Ranbaxy, Paonta Shahib, India
# 4         121600.0        3.20        0.05      Aurobindo Unit III, India
# 5           2225.6        5.35        0.02      Aurobindo Unit III, India
# 6           4374.0       32.40        0.36  MSD South Granville Australia
#
#    First Line Designation new_country  new_vendors
# 1                       1           1            1
# 3                       1           1            2
# 4                       1           1            1
# 5                       1           2            1
# 6                       1           3            3
#
# [5 rows x 22 columns]

# %%
x = df.drop(["new_vendors", "Brand", "Dosage", "Dosage Form", "Manufacturing Site", "Country", "ID", "Scheduled Delivery Date", "Delivered to Client Date", "Delivery Recorded Date", "Sub Classification", "Vendor", "Line Item Value"], axis=1)
x
# Out:
#        Fulfill Via  Shipment Mode  Product Group  Unit of Measure (Per Pack)  \
# 1                0            1.0              1                         240
# 3                0            1.0              1                          60
# 4                0            1.0              1                          60
# 5                0            1.0              1                         240
# 6                0            1.0              1                          90
# ...            ...            ...            ...                         ...
# 10319            1            2.0              1                          60
# 10320            1            2.0              1                          60
# 10321            1            2.0              1                          30
# 10322            1            2.0              1                          60
# 10323            1            2.0              1                          60
#
#        Line Item Quantity  Pack Price  Unit Price  First Line Designation  \
# 1                    1000        6.20        0.03                       1
# 3                   31920        3.99        0.07                       1
# 4                   38000        3.20        0.05                       1
# 5                     416        5.35        0.02                       1
# 6                     135       32.40        0.36                       1
# ...                   ...         ...         ...                     ...
# 10319              166571        3.60        0.06                       0
# 10320               21072        6.52        0.11                       0
# 10321              514526        9.99        0.33                       0
# 10322               17465        6.52        0.11                       1
# 10323               36639        1.99        0.03                       0
#
#        new_country
# 1                1
# 3                1
# 4                1
# 5                2
# 6                3
# ...            ...
# 10319            6
# 10320            7
# 10321            3
# 10322            6
# 10323            6
#
# [8279 rows x 9 columns]

# %%
x.isnull().sum()
# Out:
# Fulfill Via                   0
# Shipment Mode                 0
# Product Group                 0
# Unit of Measure (Per Pack)    0
# Line Item Quantity            0
# Pack Price                    0
# Unit Price                    0
# First Line Designation        0
# new_country                   0
# dtype: int64

# %%
y = df["new_vendors"]
y.isnull().sum()
# Out:
# 0

# %%
from sklearn.model_selection import train_test_split
# from sklearn.linear_model import LinearRegression

# %%
 X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.33, random_state=42)

# %%
model = LinearRegression()

# %%
model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
prediction = model.predict(X_test)
prediction
# Out:
# array([ 8.15380805, 20.20756032, 10.04053825, ...,  9.71468952,
#         8.08551773, 22.1614833 ])

# %%
np_y_test = np.array(y_test)

# %%
np_y_test
# Out:
# array([ 1, 21,  9, ...,  5,  8, 21], dtype=int64)

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error
mean_absolute_error(y_test, prediction)
# Out:
# 2.488125401670853

# %%
print("Mean Absolute Error: ", mean_absolute_error(y_test, prediction))
# Out:
# Mean Absolute Error:  2.488125401670853

# %%
mean_squared_error(y_test, prediction)
print("Root mean square error : ", np.sqrt(mean_squared_error(y_test, prediction)))
# Out:
# Root mean square error :  4.412994142838251

# %%
ind = 2
np_y_test = np.array(y_test)
actual = np_y_test[ind]
pred = round(prediction[ind], 2)
diff = round(actual - pred, 2)
prec = round(diff/actual * 100, 2)
print("Actual : " + str(actual))
print("Prediction : " +  str(pred))
print("Error : " + str(diff))
print("Error % : " + str(prec))
# Out:
# Actual : 9
# Prediction : 10.04
# Error : -1.04
# Error % : -11.56
